# %% [markdown]
# ## Data collection

# %% [markdown]
# ### read and filter dataset

# %%
# read and filter dataset
df = pd.read_csv('Datasets/Rents & Transactions/transactions.csv', sep = ';')

# dates feats
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'], errors = 'coerce', dayfirst = True)
df['dt_month'] = pd.to_datetime(df['Transaction Date'].astype(str).str[:7])
df['dt_year'] = df['Transaction Date'].astype(str).str[:4].astype(int)

df['tr_year_num'] = df['dt_year']
df['tr_month_num'] = df['dt_month'].dt.month

# filtering
# df[df.duplicated(subset = ['Transaction Number'])]
df.drop_duplicates(subset = ['Transaction Number'], keep = 'first', inplace = True)

f1 = df['Transaction Date'] > '2012-01-01'
f2 = df['Transaction Type'] == 'Sales'
filt = f1&f2
print(df.shape)
df = df[filt].sort_values('Transaction Date').reset_index(drop = True)
print(df.shape)
# Out:
# (911106, 27)
# (484311, 27)

# %%
# last property id value
feat = 'Property ID'
df[f'{feat}_last'] = df.groupby([feat]).Amount.shift(1)

# %% [markdown]
# ### cat to num or flags

# %%
# Room(s)
feat = 'Room(s)'
display(df[feat].value_counts())
df.loc[df[feat] == 'PENTHOUSE', 'Property Sub Type'] = 'PENTHOUSE'

def find_num(x):
    x1 = str(x).split(' B/R')
    if len(x1) > 1:
        return int(x1[0])
    return np.nan
    
repl1 = {k: find_num(k) for k in df[feat][~df[feat].isnull()].unique()}
repl1['Single Room'] = -1
repl1['Studio'] =  0

df[feat] = df[feat].map(repl1)
# Out:
# Room(s)
# 1 B/R          127065
# 2 B/R           87329
# Studio          81541
# 3 B/R           52704
# Office          25598
# 4 B/R           16542
# Shop             5379
# 5 B/R            1617
# PENTHOUSE         745
# Single Room       294
# 6 B/R             141
# Store Room         33
# 7 B/R              24
# Hotel               7
# GYM                 6
# 8 B/R               2
# Name: count, dtype: int64

# %%
# flags
feat = 'Usage'
repl1 = {'Residential': 1}
df[feat] = df[feat].map(repl1).fillna(0).astype(int)

feat = 'Registration type'
repl1 = {'Ready': 1}
df[feat] = df[feat].map(repl1).fillna(0).astype(int)

feat = 'Is Free Hold?'
repl1 = {'Free Hold': 1}
df[feat] = df[feat].map(repl1).fillna(0).astype(int)

feat = 'Parking'
df[feat] = df[feat].notnull().astype(int)

# %% [markdown]
# ### cats cleaning - unpopular as null

# %%
cnt_min = 99

# %%
# Property Type
feat = 'Property Type'
repl1 = {}
df[feat] = df[feat].fillna('').str.strip().map(lambda x: repl1[x] if x in repl1 else x)
df[feat].value_counts()
# Out:
# Property Type
# Unit        359012
# Land         82583
# Building     42716
# Name: count, dtype: int64

# %%
# Property Sub Type
feat = 'Property Sub Type'
df[feat] = df['Property Type'] + '_' + df[feat].fillna('')

repl1 = {}
df[feat] = df[feat].fillna('').str.strip().map(lambda x: repl1[x] if x in repl1 else x)

repl1 = df[feat].value_counts()
repl1 = repl1[repl1 > cnt_min]
df[feat] = df[feat].map(lambda x: x if x in repl1.index else '')
df[feat].value_counts()
# Out:
# Property Sub Type
# Unit_Flat                  299139
# Building_Villa              42616
# Land_Residential            42508
# Unit_Office                 26607
# Land_Commercial             23953
# Unit_Hotel Apartment        17270
# Unit_Hotel Rooms             8920
# Land_                        7158
# Unit_Shop                    5641
# Land_Residential Flats       1773
# Land_Villa                   1736
# Land_Land                    1284
# Land_Industrial              1022
# Land_General Use              880
# Unit_PENTHOUSE                745
# Land_Airport                  420
#                               408
# Land_Unit                     400
# Land_Labor Camp               318
# Land_Government Housing       316
# Land_Sports Club              305
# Unit_Stacked Townhouses       270
# Unit_Workshop                 211
# Land_Agricultural             195
# Land_Warehouse                116
# Building_Building             100
# Name: count, dtype: int64

# %%
# Nearest Landmark
feat = 'Nearest Landmark'
repl1 = {}
df[feat] = df[feat].fillna('').str.strip().map(lambda x: repl1[x] if x in repl1 else x)

repl1 = df[feat].value_counts()
repl1 = repl1[repl1 > cnt_min]
df[feat] = df[feat].map(lambda x: x if x in repl1.index else '')
df[feat].value_counts()
# Out:
# Nearest Landmark
# Sports City Swimming Academy         103307
# Burj Al Arab                          79980
# Downtown Dubai                        72086
#                                       49371
# Motor City                            37189
# IMG World Adventures                  32561
# Burj Khalifa                          26884
# Dubai Cycling Course                  24681
# Dubai International Airport           22804
# Expo 2020 Site                        20995
# Global Village                         4344
# Al Makhtoum International Airport      3867
# Dubai Parks and Resorts                3168
# Hamdan Sports Complex                  3074
# Name: count, dtype: int64

# %%
# Nearest Mall
feat = 'Nearest Mall'
repl1 = {}
df[feat] = df[feat].fillna('').str.strip().map(lambda x: repl1[x] if x in repl1 else x)

repl1 = df[feat].value_counts()
repl1 = repl1[repl1 > cnt_min]
df[feat] = df[feat].map(lambda x: x if x in repl1.index else '')
df[feat].value_counts()
# Out:
# Nearest Mall
# Marina Mall             146364
#                         121528
# Dubai Mall              104383
# Mall of the Emirates     44436
# City Centre Mirdif       39872
# Ibn-e-Battuta Mall       27728
# Name: count, dtype: int64

# %%
# Nearest Metro
feat = 'Nearest Metro'
repl1 = {
    'Jumeirah Beach Resdency': 'Jumeirah Beach Residency'
}
df[feat] = df[feat].fillna('').str.strip().map(lambda x: repl1[x] if x in repl1 else x)

repl1 = df[feat].value_counts()
repl1 = repl1[repl1 > cnt_min]
df[feat] = df[feat].map(lambda x: x if x in repl1.index else '')
df[feat].value_counts()
# Out:
# Nearest Metro
#                                         120606
# Buj Khalifa Dubai Mall Metro Station     48572
# Business Bay Metro Station               39306
# Nakheel Metro Station                    32801
# Dubai Internet City                      27680
# Rashidiya Metro Station                  27639
# Damac Properties                         24042
# Jumeirah Lakes Towers                    23169
# Jumeirah Beach Residency                 19367
# First Abu Dhabi Bank Metro Station       13514
# Sharaf Dg Metro Station                  11409
# Ibn Battuta Metro Station                10626
# Harbour Tower                            10421
# Creek Metro Station                       9842
# Mina Seyahi                               9827
# Palm Jumeirah                             9229
# Marina Towers                             6250
# Noor Bank Metro Station                   5457
# DANUBE Metro Station                      5335
# Marina Mall Metro Station                 4098
# Dubai Marina                              3854
# Trade Centre Metro Station                3011
# Al Jadaf Metro Station                    2166
# UAE Exchange Metro Station                1905
# Financial Centre                          1842
# Al Sufouh                                 1822
# Healthcare City Metro Station             1155
# Knowledge Village                         1151
# Etisalat Metro Station                    1106
# ENERGY Metro Station                       905
# Al Jafiliya Metro Station                  778
# Abu Baker Al Siddique Metro Station        719
# Abu Hail Metro Station                     585
# Emirates Towers Metro Station              579
# Emirates Metro Station                     477
# Deira City Centre                          472
# Salah Al Din Metro Station                 343
# Al Ghubaiba Metro Station                  320
# Palm Deira Metro Stations                  299
# Al Fahidi Metro Station                    228
# Al Qusais Metro Station                    213
# Al Qiyadah Metro Station                   211
# Al Rigga Metro Station                     210
# Baniyas Square Metro Station               173
# Airport Free Zone                          156
# ADCB Metro Station                         152
# Al Ras Metro Station                       147
# Al Nahda Metro Station                     142
# Name: count, dtype: int64

# %%
# Project
feat = 'Project'
print(df[feat].nunique())
df[feat] = df[feat].str.lower().str.strip()
print(df[feat].nunique())

repl1 = df[feat].value_counts()
repl1 = repl1[repl1 > cnt_min]
df[feat] = df[feat].map(lambda x: x if x in repl1.index else '')
print(df[feat].nunique())
df[feat].value_counts()
# Out:
# 1411
# 1411
# 921
# Project
#                                   140441
# remraam                             4421
# sky courts                          2576
# international city emarati          2565
# al khail heights                    2344
#                                    ...
# canal front residences-cf3&cf4       102
# azizi riviera 18                     101
# city center residences               101
# polo homes                           100
# sahara meadows2                      100
# Name: count, Length: 921, dtype: int64

# %%
# Project
feat = 'Area'
print(df[feat].nunique())
df[feat] = df[feat].str.lower().str.strip()
print(df[feat].nunique())

repl1 = df[feat].value_counts()
repl1 = repl1[repl1 > cnt_min]
df[feat] = df[feat].map(lambda x: x if x in repl1.index else '')
print(df[feat].nunique())
df[feat].value_counts()
# Out:
# 305
# 299
# 160
# Area
# business bay                         41177
# dubai marina                         34254
# burj khalifa                         28358
# jumeirah village circle              26535
# jumeirah lakes towers                26527
# international city ph 1              21628
# dubai sports city                    17275
# palm jumeirah                        14650
# silicon oasis                        13647
# dubai hills                          11442
# akoya oxygen                          9934
# al furjan                             9577
# dubai creek harbour                   9390
# damac hills                           8696
# town square                           7699
# dubai production city                 7082
# arjan                                 7001
# the greens                            6571
# jumeirah beach residence              6514
# dubai investment park first           6461
# emirate living                        5940
# mira                                  5628
# jumeirah village triangle             5552
# remraam                               4755
# discovery gardens                     4619
# jumeirah park                         4485
# dubai south                           4459
# sobha heartland                       4301
# meydan one                            4259
# motor city                            4251
# liwan                                 4150
# arabian ranches i                     4083
# dubai land residence complex          4052
# dubai harbour                         4047
# villanova                             3650
# barsha heights                        3623
#                                       3478
# emaar south                           3078
# jabel ali hills                       2812
# dubai investment park second          2742
# arabian ranches ii                    2594
# mbr district 1                        2480
# al hebiah fifth                       2356
# al khail heights                      2347
# city walk                             2323
# jumeirah golf                         2305
# al hebiah third                       2217
# zaabeel second                        2175
# the lakes                             2113
# arabian ranches iii                   2057
# the villa                             1895
# serena                                1854
# mirdif                                1796
# la mer                                1793
# jabal ali first                       1771
# dubai science park                    1640
# living legends                        1623
# dubai healthcare city - phase 2       1608
# mbr district 7                        1572
# al hebiah fourth                      1552
# meydan avenue                         1533
# jaddaf waterfront                     1498
# al yelayiss 2                         1475
# international city ph 2 & 3           1470
# tilal al ghaf                         1255
# down town jabal ali                   1211
# nad al shiba third                    1211
# wadi al safa 5                        1124
# dubai studio city                     1056
# mudon                                  936
# dubai industrial city                  931
# jumeirah living                        922
# bluewaters                             898
# al barari                              864
# marsa dubai                            837
# the valley                             759
# hor al anz                             754
# wadi al safa 3                         747
# nad al sheba gardens                   732
# jumeirah islands                       721
# al kifaf                               697
# al wasl                                693
# the world                              685
# sufouh gardens                         663
# falcon city of wonders                 645
# muhaisanah first                       637
# grand views                            620
# tecom site a                           609
# al satwa                               590
# pearl jumeira                          566
# al kheeran                             558
# dmcc-ez2                               533
# port saeed                             500
# warsan first                           486
# al khawaneej first                     481
# al rashidiya                           469
# madinat al mataar                      461
# jumeira bay                            454
# jumeirah heights                       441
# cherrywoods                            435
# sustainable city                       434
# wadi al safa 7                         414
# nad al hamar                           393
# jabal ali                              389
# jabal ali industrial first             386
# majan                                  381
# asmaran                                369
# al yufrah 2                            363
# dubai water canal                      356
# al bada                                351
# dubai golf city                        339
# al barsha first                        338
# the field                              337
# millennium                             325
# al yufrah 1                            312
# nad al shiba                           300
# jumeirah first                         286
# al merkadh                             282
# al waha                                281
# al ruwayyah                            278
# me'aisem first                         273
# abu hail                               266
# trade center second                    259
# al barsha third                        254
# trade center first                     238
# um al sheif                            237
# al warqa first                         234
# al waheda                              230
# rukan                                  230
# al barsha second                       228
# al muteena                             200
# dubai maritime city                    189
# liwan 2                                186
# al mezhar first                        183
# dubai healthcare city - phase 1        183
# al mamzer                              178
# palmarosa                              176
# dubai water front                      170
# nad al shiba first                     168
# sama al jadaf                          164
# polo townhouses igo                    157
# naif                                   155
# al suq al kabeer                       154
# um suqaim second                       149
# al mararr                              145
# al thanyah fifth                       137
# al warqa third                         131
# al raffa                               128
# um suqaim first                        128
# hadaeq sheikh mohammed bin rashid      127
# al barshaa south third                 126
# city of arabia                         124
# rega al buteen                         118
# island 2                               115
# al mezhar second                       113
# al manara                              111
# al goze first                          111
# al karama                              109
# al dhagaya                             103
# arabian ranches polo club              100
# Name: count, dtype: int64

# %% [markdown]
# ### cats encoding

# %%
# categorical feats encoding
feats_cat = [    
    'Property Type',
    'Property Sub Type',
    'Area',
    'Nearest Metro',
    'Nearest Mall',
    'Nearest Landmark',
    'Project',
]

# label encoder
for feat in feats_cat:
    lbl = preprocessing.LabelEncoder()
    df[f'{feat}_lbl'] = lbl.fit_transform(df[feat])
    

# one-hot maybe..
# lbl = preprocessing.OneHotEncoder(sparse_output=False, drop='first')
# df = pd.concat([df, pd.DataFrame(lbl.fit_transform(df[[f+'_lbl']]), columns = lbl.get_feature_names_out())], axis = 1)
# del df[f+'_lbl']

# %%
# target encoders by average value in the previous month
for feat in feats_cat[1:]:
    feats_gr = ['dt_month', 'Property Type', feat]
    df1 = df.groupby(feats_gr).Amount.mean().reset_index()
    df1[f'{feat}_trg'] = df1.groupby(feats_gr[1:]).Amount.shift(1)
    del df1['Amount']    
    df = df.merge(df1, how = 'left')

# %%
df[df['Transaction Date'] < '2022-06-01'].to_pickle('data1.pkl')
print(df.shape)
df[:5]
# Out:
# (484311, 41)
#   Transaction Number    Transaction Date  Property ID Transaction Type  \
# 0          11-1-2012 2012-01-02 08:16:00       236028            Sales
# 1          11-2-2012 2012-01-02 08:22:00        90111            Sales
# 2       41-8804-2010 2012-01-02 08:35:00       738093            Sales
# 3          11-4-2012 2012-01-02 08:36:00       426717            Sales
# 4          11-3-2012 2012-01-02 08:39:00       567015            Sales
#
#   Transaction sub type  Registration type  Is Free Hold?  Usage  \
# 0                 Sale                  1              0      0
# 1                 Sale                  1              0      1
# 2         Delayed Sell                  1              1      1
# 3                 Sale                  1              1      1
# 4                 Sale                  1              1      1
#
#                Area Property Type Property Sub Type       Amount  \
# 0  al suq al kabeer          Land   Land_Commercial 2,400,000.00
# 1            mirdif          Land  Land_Residential 2,784,375.00
# 2     palm jumeirah          Unit         Unit_Flat 2,662,200.00
# 3    emirate living      Building    Building_Villa 1,290,000.00
# 4      burj khalifa          Unit         Unit_Flat 1,610,000.00
#
#    Transaction Size (sq.m)  Property Size (sq.m)  Room(s)  Parking  \
# 0                   201.79                201.79      NaN        0
# 1                   940.64                940.64      NaN        0
# 2                   190.05                190.05     2.00        1
# 3                   165.51                165.51     2.00        0
# 4                   113.43                113.43     2.00        1
#
#                           Nearest Metro        Nearest Mall  \
# 0             Al Ghubaiba Metro Station          Dubai Mall
# 1               Rashidiya Metro Station  City Centre Mirdif
# 2                         Palm Jumeirah         Marina Mall
# 3                      Damac Properties         Marina Mall
# 4  Buj Khalifa Dubai Mall Metro Station          Dubai Mall
#
#                Nearest Landmark  No. of Buyer  No. of Seller Master Project  \
# 0                  Burj Khalifa          1.00           1.00            NaN
# 1   Dubai International Airport          1.00           1.00            NaN
# 2                  Burj Al Arab          1.00           1.00            NaN
# 3  Sports City Swimming Academy          1.00           1.00            NaN
# 4                Downtown Dubai          1.00           1.00            NaN
#
#             Project   dt_month  dt_year  tr_year_num  tr_month_num  \
# 0                   2012-01-01     2012         2012             1
# 1                   2012-01-01     2012         2012             1
# 2  marina residence 2012-01-01     2012         2012             1
# 3                   2012-01-01     2012         2012             1
# 4                   2012-01-01     2012         2012             1
#
#    Property ID_last  Property Type_lbl  Property Sub Type_lbl  Area_lbl  \
# 0               NaN                  1                      6        31
# 1               NaN                  1                     12       116
# 2               NaN                  2                     18       126
# 3               NaN                  0                      2        78
# 4               NaN                  2                     18        49
#
#    Nearest Metro_lbl  Nearest Mall_lbl  Nearest Landmark_lbl  Project_lbl  \
# 0                  6                 2                     3            0
# 1                 43                 1                     6            0
# 2                 42                 5                     2          522
# 3                 20                 5                    13            0
# 4                 16                 2                     4            0
#
#    Property Sub Type_trg  Area_trg  Nearest Metro_trg  Nearest Mall_trg  \
# 0                    NaN       NaN                NaN               NaN
# 1                    NaN       NaN                NaN               NaN
# 2                    NaN       NaN                NaN               NaN
# 3                    NaN       NaN                NaN               NaN
# 4                    NaN       NaN                NaN               NaN
#
#    Nearest Landmark_trg  Project_trg
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4                   NaN          NaN

# %%
list(df.columns)
# Out:
# ['Transaction Number',
#  'Transaction Date',
#  'Property ID',
#  'Transaction Type',
#  'Transaction sub type',
#  'Registration type',
#  'Is Free Hold?',
#  'Usage',
#  'Area',
#  'Property Type',
#  'Property Sub Type',
#  'Amount',
#  'Transaction Size (sq.m)',
#  'Property Size (sq.m)',
#  'Room(s)',
#  'Parking',
#  'Nearest Metro',
#  'Nearest Mall',
#  'Nearest Landmark',
#  'No. of Buyer',
#  'No. of Seller',
#  'Master Project',
#  'Project',
#  'dt_month',
#  'dt_year',
#  'tr_year_num',
#  'tr_month_num',
#  'Property ID_last',
#  'Property Type_lbl',
#  'Property Sub Type_lbl',
#  'Area_lbl',
#  'Nearest Metro_lbl',
#  'Nearest Mall_lbl',
#  'Nearest Landmark_lbl',
#  'Project_lbl',
#  'Property Sub Type_trg',
#  'Area_trg',
#  'Nearest Metro_trg',
#  'Nearest Mall_trg',
#  'Nearest Landmark_trg',
#  'Project_trg']
